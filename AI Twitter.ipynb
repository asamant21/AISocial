# %%
from aisocial.main import generate_post
from aisocial.Topic import topic_cache, generate_new_topics, add_user_recommended_topics
from aisocial.Post import post_cache

# %%
topics = ["cats", "dogs", "classic cars", "brutalism", "corvettes"]
add_user_recommended_topics(topics)

# %%
post_list = []
for i in range(3):
    post_list.append(generate_post())

# %%
for post in post_list:
    post.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>

# %%
post_list[2].like()

# %%
generate_new_topics()

# %%
post_list = []
for i in range(3):
    post_list.append(generate_post())

# %%
for post in post_list:
    post.show()
# Out:
# Just asked my cats and dogs who likes classic cars and brutalism architecture better... They all looked at me like I had three heads 😂 #Canines #Felines #MuscleCars #Corvettes #HighPerformanceVehicles
# Just saw an old Corvette pass by and it reminded me why cats and dogs will never come close to the beauty and style of classic cars! #MuscleCars #High-PerformanceVehicles #Felines #Canines #Brutalism #Architecture
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>
