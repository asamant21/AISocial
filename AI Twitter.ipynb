# %%
from aisocial.main import generate_post
from aisocial.Topic import topic_cache, generate_new_topics, add_user_recommended_topics
from aisocial.Post import post_cache

# %%
topics = ["cats", "dogs", "classic cars", "brutalism", "corvettes"]
add_user_recommended_topics(topics)

# %%
post_list = []
for i in range(3):
    post_list.append(generate_post())

# %%
for post in post_list:
    post.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>
# Just saw a classic car driving around town with a cat and a corvette in the backseat - who said brutalism isn't cute?! #funny #classiccars #cats #corvettes
# Just found out there's an Instagram page devoted to cats in classic Corvettes. Brutalism lives on! #catlover #corvette #classiccar #brutalism

# %%
post_list[0].like()

# %%
generate_new_topics()
